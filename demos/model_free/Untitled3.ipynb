# %%
import REINFORCE_acrobot
# Out:
# Mean reward:  -1.1643211237980666-6.142697114239583465
# Std Deviation:  20.88362228271622
# Variance:  0.14537522654905383
# Overall mean reward:  -1.1643211237980666
# Overall std deviation:  20.88362228271622
# Overall variance:  0.14537522654905383
