# %%
import REINFORCE
# Out:
# Episode: 1999 Score: 28.00
# Mean reward:  260.218
# Std Deviation:  202.55992134888982
# Variance:  20.515260868434215
# Episode: 1999 Score: 500.0
# Mean reward:  262.305
# Std Deviation:  233.4217574122359
# Variance:  27.242858416708355
# Episode: 1999 Score: 500.0
# Mean reward:  404.175
# Std Deviation:  187.03268427602097
# Variance:  17.490612493746873
# Episode: 1999 Score: 500.0
# Mean reward:  438.9695
# Std Deviation:  82.44856853200356
# Variance:  3.398883226488244

# %%
print("Mean reward: ",REINFORCE.stats.mean(REINFORCE.episode_rewards))
# Out:
# Mean reward:  341.416875
