# %%
import REINFORCE
# Out:
# Episode: 1999 Score: 356.0
# Mean reward:  322.2325
# Std Deviation:  138.86104435214827
# Variance:  9.641194819284642
# Episode: 1999 Score: 500.0
# Mean reward:  454.0725
# Std Deviation:  86.18185365667097
# Variance:  3.713655949849925
# Episode: 1999 Score: 397.0
# Mean reward:  487.293
# Std Deviation:  42.29665062776441
# Variance:  0.8945033271635817
# Episode: 1999 Score: 500.0
# Mean reward:  493.7585
# Std Deviation:  31.70687371328708
# Variance:  0.5026629203351676

# %%
print("Mean reward: ",REINFORCE.stats.mean(REINFORCE.episode_rewards))
# Out:
# Mean reward:  439.339125
