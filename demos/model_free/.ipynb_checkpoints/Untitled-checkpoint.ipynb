# %%
import REINFORCE_cartpole
# Out:
# Episode: 842 Score: 30.0616505151660658
# You Win!
#
# Mean reward:  -1188.8630737261237607953
# Std Deviation:  370.3260224814127
# Variance:  137.14136292690375
# Overall mean reward:  -1188.8630737261237
# Overall std deviation:  370.3260224814127
# Overall variance:  137.14136292690375
