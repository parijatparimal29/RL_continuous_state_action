# %%
import REINFORCE_mountain
# Out:
# 0.5052907469050522 21.87377731400218 Max height: -0.2921288406219162456
# Car has reached the goal
#
# 0.508487535006177: 5.1624888201813715 Max height: -0.24213596355261474
# Car has reached the goal
#
# Mean reward:  37.05923654892815451325 Max height: -0.0289537911987896826
# Std Deviation:  28.910587963106277
# Variance:  6.9651841364375455
# Overall mean reward:  37.05923654892815
# Overall std deviation:  28.910587963106277
# Overall variance:  6.9651841364375455
